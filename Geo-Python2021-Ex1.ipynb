# %%
#Declaring variables
ice_cream_rating=8
sleeping_rating=9

# average value
happiness_rating = (ice_cream_rating+sleeping_rating)/2.0

# %%
# Get user name data
first_name=input('First Name?')
# Out:
# First Name? EJ

# %%
last_name=input('LastName?')
# Out:
# LastName? PS

# %%
#Combine first and last with a space between them
my_name = first_name + ' '+last_name
print (my_name)
# Out:
# EJ PS

# %%
type(happiness_rating)
# Out:
# float

# %%
type(first_name)
# Out:
# str

# %%
type(ice_cream_rating)
# Out:
# int

# %%
print('My name is',first_name,'and I give eating ice cream a score of ',ice_cream_rating,'out of 10!')
# Out:
# My name is EJ and I give eating ice cream a score of  8 out of 10!
